# %%
import pandas as pd
from kozak_pipe import run_kozak

# %%
# You prepare df however you like (from CSV, DB, whatever)
df = pd.read_csv("Stock level signals.csv")

results = run_kozak(df)
# Out:
# Dropping 17 columns with >25% NaNs:
# ['ipo', 'invaci', 'sue', 'shortint', 'indmomrev', 'indrrevlv', 'gltnoa', 'dur', 'divg', 'divp', 'roa', 'accruals', 'noa', 'valmomprof', 'valprof', 'valmom', 'roe']
# NaN summary after dropping columns >25% NaN:
#         column  null_count   null_pct
# 0          ipo      684662  93.438983
# 1       invaci      672841  91.825716
# 2          sue      505599  69.001429
# 3     shortint      302432  41.274291
# 4    indmomrev      291482  39.779894
# 5    indrrevlv      291480  39.779621
# 6       gltnoa      285706  38.991616
# 7          dur      266383  36.354517
# 8         divg      249420  34.039498
# 9         divp      234980  32.068805
# 10         roa      226245  30.876699
# 11    accruals      200760  27.398644
# 12         noa      192980  26.336871
# 13  valmomprof      188981  25.791109
# 14     valprof      184672  25.203040
# 15      valmom      184486  25.177656
# 16         roe      183234  25.006790
# 17         inv      173582  23.689537
# 18        rome      173265  23.646274
# 19     igrowth      164457  22.444206
# 20      invcap      139657  19.059635
# 21         cfp      128597  17.550226
# 22        ciss      119069  16.249896
# 23       lrrev      118840  16.218643
# 24      season      116168  15.853983
# 25     repurch      103910  14.181077
# 26     debtiss      103910  14.181077
# 27     sgrowth       89901  12.269204
# 28      growth       88033  12.014270
# 29       value       76177  10.396227
# 30        roea       75755  10.338634
# 31     betaarb       72712   9.923342
# 32        prof       69981   9.550630
# 33          ep       64556   8.810255
# 34    gmargins       64543   8.808481
# 35   aturnover       64324   8.778593
# 36          sp       64247   8.768085
# 37         lev       63068   8.607181
# 38      valuem       63007   8.598856
# 39        roaa       62941   8.589849
# 40      momrev       37652   5.138542
# 41       nissa       34634   4.726662
# 42       shvol       28473   3.885842
# 43       nissm       24325   3.319745
# 44       mom12       23285   3.177811
# 45         mom       19174   2.616764
# 46        size       11472   1.565637
# 47        ivol        7935   1.082926
# 48      indmom        3735   0.509733
# 49     indrrev        3730   0.509050
# 50          re         236   0.032208
# 51       strev           0   0.000000
# 52      fscore           0   0.000000
# 53       price           0   0.000000
# 54         age           0   0.000000
# 55        date           0   0.000000
# 56      permno           0   0.000000
# Shape after dropping columns:  ['ipo', 'invaci', 'sue', 'shortint', 'indmomrev', 'indrrevlv', 'gltnoa', 'dur', 'divg', 'divp', 'roa', 'accruals', 'noa', 'valmomprof', 'valprof', 'valmom', 'roe']

# %%
df_ols_sr2   = results["df_ols_sr2"]
df_ols_impr  = results["df_ols_impr"]
df_uni_sr2   = results["df_uni_sr2"]
df_uni_impr  = results["df_uni_impr"]

# Then you can recreate your notebook plots:
import matplotlib.pyplot as plt

df_ols_sr2.plot(marker="o")
plt.xlabel("Number of factors K")
plt.ylabel("Average total SR$^2$ (annualized) - OLS")
plt.show()

df_uni_sr2.plot(marker="o")
plt.xlabel("Number of factors K")
plt.ylabel("Average total SR$^2$ (annualized) - UNI")
plt.show()
